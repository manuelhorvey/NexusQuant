# %% [markdown]
# # NexusQuant — Quick Start
#
# This notebook shows how to load data, compute features, detect regime, and generate an institutional-style report.

# %%
import sys
sys.path.append("..")

import pandas as pd
from pathlib import Path

from src.data.loader import load_data, clean_data, save_processed
from src.features.indicators import add_all_indicators
from src.features.regime import detect_regime
from src.analysis.report import generate_full_report, print_report

# %% [markdown]
# ## 1. Load & Clean Your Data
#
# Place your MT5 export (CSV) into `data/raw/` then update the path below.

# %%
# Example — update this path to your file
raw_path = "../data/raw/your_xauusd_data.csv"  # ← change this

# df = load_data(raw_path, symbol="XAUUSD")
# df = clean_data(df)
# print(df.tail())
# print(df.shape)

# %% [markdown]
# ## 2. Add Indicators + Regime

# %%
# df = add_all_indicators(df)
# df = detect_regime(df)
# df.tail(3)

# %% [markdown]
# ## 3. Generate Full Institutional Report

# %%
# report = generate_full_report(df, symbol="XAUUSD")
# print_report(report)

# %% [markdown]
# ## 4. Save Processed Data (recommended)

# %%
# save_processed(df, symbol="XAUUSD", timeframe="D1")
